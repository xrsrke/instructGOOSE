# %% [raw]
# ---
# description: Fill in a module description here
# output-file: actor.html
# title: actor
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Actor)
# Out:
# ---
#
# [source](https://github.com/xrsrke/instructGOOSE/blob/main/instruct_goose/actor.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### Actor
#
# >      Actor (env, model, tokenizer)
#
# Initialize self.  See help(type(self)) for accurate signature.
