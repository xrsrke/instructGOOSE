# %% [raw]
# ---
# description: Fill in a module description here
# output-file: utils.html
# title: utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(load_yaml)
# Out:
# ---
#
# [source](https://github.com/xrsrke/instructGOOSE/blob/main/instruct_goose/utils.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_yaml
#
# >      load_yaml (config_path)

# %%
#| echo: false
#| output: asis
show_doc(RLHFConfig)
# Out:
# ---
#
# [source](https://github.com/xrsrke/instructGOOSE/blob/main/instruct_goose/utils.py#L21){target="_blank" style="float:right; font-size:smaller"}
#
# ### RLHFConfig
#
# >      RLHFConfig (epsilon:float=0.1, ent_coef:float=0.01, vf_coef:float=0.1)

# %%
#| echo: false
#| output: asis
show_doc(ReplayBuffer)
# Out:
# ---
#
# [source](https://github.com/xrsrke/instructGOOSE/blob/main/instruct_goose/utils.py#L29){target="_blank" style="float:right; font-size:smaller"}
#
# ### ReplayBuffer
#
# >      ReplayBuffer ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %% [markdown]
# ### Reference Model

# %%
#| echo: false
#| output: asis
show_doc(create_reference_model)
# Out:
# ---
#
# [source](https://github.com/xrsrke/instructGOOSE/blob/main/instruct_goose/utils.py#L57){target="_blank" style="float:right; font-size:smaller"}
#
# ### create_reference_model
#
# >      create_reference_model (model)

# %%
import torch
torch.randint(low=0, high=10, size=(1,))
# Out:
# tensor([7])
