# %% [raw]
# ---
# description: Fill in a module description here
# output-file: utils.html
# title: utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(load_yaml)
# Out:
# ---
#
# [source](https://github.com/xrsrke/instructGOOSE/blob/main/instruct_goose/utils.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### load_yaml
#
# >      load_yaml (config_path)

# %%
# #| export
# def create_small_dataset(large_dataset):
#     dataset = {}
    
#     for idx in range(len(large_dataset)):
#         dataset[idx] = {
#             "promopt": large_dataset["prompt"][idx],
#             "chosen": large_dataset["chosen"][idx],
#             "rejected": large_dataset["rejected"][idx]
#         }
    
#     return dataset
