# %% [raw]
# ---
# description: Fill in a module description here
# output-file: dataset.html
# title: dataset
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ### Dataset for Reward Model

# %%
#| echo: false
#| output: asis
show_doc(PairDataset)
# Out:
# ---
#
# [source](https://github.com/xrsrke/instructGOOSE/blob/main/instruct_goose/dataset.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### PairDataset
#
# >      PairDataset (dataset, tokenizer:Callable, max_length:int=1024)
#
# An abstract class representing a :class:`Dataset`.
#
# All datasets that represent a map from keys to data samples should subclass
# it. All subclasses should overwrite :meth:`__getitem__`, supporting fetching a
# data sample for a given key. Subclasses could also optionally overwrite
# :meth:`__len__`, which is expected to return the size of the dataset by many
# :class:`~torch.utils.data.Sampler` implementations and the default options
# of :class:`~torch.utils.data.DataLoader`.
#
# .. note::
#   :class:`~torch.utils.data.DataLoader` by default constructs a index
#   sampler that yields integral indices.  To make it work with a map-style
#   dataset with non-integral indices/keys, a custom sampler must be provided.

# %% [markdown]
# ### Dataset for PPO Agent

# %%
#| echo: false
#| output: asis
show_doc(PromptDataset)
# Out:
# ---
#
# [source](https://github.com/xrsrke/instructGOOSE/blob/main/instruct_goose/dataset.py#L54){target="_blank" style="float:right; font-size:smaller"}
#
# ### PromptDataset
#
# >      PromptDataset (dataset, tokenizer:Callable, max_length:int)
#
# An abstract class representing a :class:`Dataset`.
#
# All datasets that represent a map from keys to data samples should subclass
# it. All subclasses should overwrite :meth:`__getitem__`, supporting fetching a
# data sample for a given key. Subclasses could also optionally overwrite
# :meth:`__len__`, which is expected to return the size of the dataset by many
# :class:`~torch.utils.data.Sampler` implementations and the default options
# of :class:`~torch.utils.data.DataLoader`.
#
# .. note::
#   :class:`~torch.utils.data.DataLoader` by default constructs a index
#   sampler that yields integral indices.  To make it work with a map-style
#   dataset with non-integral indices/keys, a custom sampler must be provided.
